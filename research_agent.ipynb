# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Agent, Task, Crew
import os
from utils import get_openai_api_key

# %%
openai_api_key = get_openai_api_key()
print("OpenAI API Key:", openai_api_key)
os.environ["OPENAI_MODEL_NAME"]="gpt-3.5-turbo"
# Out:
# OpenAI API Key: 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

# %%
planner = Agent(
    role="Content Planner",
    goal="Plan engaging and factually accurate content on {topic}",
    backstory="You're working on planning a blog article "
              "about the topic: {topic}."
              "You collect information that helps the "
              "audience learn something "
              "and make informed decisions. "
              "Your work is the basis for "
              "the Content Writer to write an article on this topic.",
    allow_delegation=False,
	verbose=True
)

# %%
writer = Agent(
    role="Content Writer",
    goal="Write insightful and factually accurate "
         "opinion piece about the topic: {topic}",
    backstory="You're working on a writing "
              "a new opinion piece about the topic: {topic}. "
              "You base your writing on the work of "
              "the Content Planner, who provides an outline "
              "and relevant context about the topic. "
              "You follow the main objectives and "
              "direction of the outline, "
              "as provide by the Content Planner. "
              "You also provide objective and impartial insights "
              "and back them up with information "
              "provide by the Content Planner. "
              "You acknowledge in your opinion piece "
              "when your statements are opinions "
              "as opposed to objective statements.",
    allow_delegation=False,
    verbose=True
)

# %%
editor = Agent(
    role="Editor",
    goal="Edit a given blog post to align with "
         "the writing style of the organization. ",
    backstory="You are an editor who receives a blog post "
              "from the Content Writer. "
              "Your goal is to review the blog post "
              "to ensure that it follows journalistic best practices,"
              "provides balanced viewpoints "
              "when providing opinions or assertions, "
              "and also avoids major controversial topics "
              "or opinions when possible.",
    allow_delegation=False,
    verbose=True
)

# %%
plan = Task(
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output="A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources.",
    agent=planner,
)

# %%
write = Task(
    description=(
        "1. Use the content plan to craft a compelling "
            "blog post on {topic}.\n"
        "2. Incorporate SEO keywords naturally.\n"
		"3. Sections/Subtitles are properly named "
            "in an engaging manner.\n"
        "4. Ensure the post is structured with an "
            "engaging introduction, insightful body, "
            "and a summarizing conclusion.\n"
        "5. Proofread for grammatical errors and "
            "alignment with the brand's voice.\n"
    ),
    expected_output="A well-written blog post "
        "in markdown format, ready for publication, "
        "each section should have 2 or 3 paragraphs.",
    agent=writer,
)

# %%
edit = Task(
    description=("Proofread the given blog post for "
                 "grammatical errors and "
                 "alignment with the brand's voice."),
    expected_output="A well-written blog post in markdown format, "
                    "ready for publication, "
                    "each section should have 2 or 3 paragraphs.",
    agent=editor
)

# %%
crew = Crew(
    agents=[planner, writer, editor],
    tasks=[plan, write, edit],
    verbose=False
)

# %%
result = crew.kickoff(inputs={"topic": "Artificial Intelligence"})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │  Task: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.            │
# │  2. Identify the target audience, considering their interests and pain points.                                  │
# │  3. Develop a detailed content outline including an introduction, key points, and a call to action.             │
# │  4. Include SEO keywords and relevant data or sources.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Content Plan: Unveiling Artificial Intelligence: Trends, Players, & News                                       │
# │                                                                                                                 │
# │  Audience Analysis:                                                                                             │
# │  Target Audience: Professionals in technology sectors, small business owners seeking AI solutions, and          │
# │  individuals interested in cutting-edge tech advancements.                                                      │
# │  Interests: Exploring AI trends, understanding key industry players, staying updated on AI news, implementing   │
# │  AI in business operations.                                                                                     │
# │  Pain Points: Confusion around AI implementation, staying current in a rapidly evolving field, concerns about   │
# │  job displacement due to automation.                                                                            │
# │                                                                                                                 │
# │  SEO Keywords:                                                                                                  │
# │  1. Artificial Intelligence trends 2021                                                                         │
# │  2. Key players in AI industry                                                                                  │
# │  3. Latest Artificial Intelligence news                                                                         │
# │  4. AI solutions for businesses                                                                                 │
# │  5. Implementing AI technologies                                                                                │
# │                                                                                                                 │
# │  Outline:                                                                                                       │
# │  I. Introduction                                                                                                │
# │  - Definition of Artificial Intelligence and its significance                                                   │
# │  - Teaser of the latest AI trends, key players, and recent news                                                 │
# │                                                                                                                 │
# │  II. Latest Trends in Artificial Intelligence                                                                   │
# │  A. Advancements in Machine Learning and Deep Learning                                                          │
# │  B. Rise of Conversational AI and Chatbots                                                                      │
# │  C. AI-powered Automation in Business Processes                                                                 │
# │  D. Exploring Ethical AI and Bias Mitigation                                                                    │
# │                                                                                                                 │
# │  III. Key Players Shaping the AI Landscape                                                                      │
# │  A. Tech Titans: Google, Amazon, Microsoft, Apple                                                               │
# │  B. Leading AI Research Institutes: MIT AI Lab, Stanford HAI                                                    │
# │  C. Emerging AI Startups Revolutionizing Industries                                                             │
# │                                                                                                                 │
# │  IV. Noteworthy News in the Artificial Intelligence World                                                       │
# │  A. Breakthroughs in AI Research and Applications                                                               │
# │  B. AI's Impact on Employment and Reskilling Initiatives                                                        │
# │  C. Regulatory Updates and Ethical Frameworks in AI Development                                                 │
# │                                                                                                                 │
# │  V. Implementing AI Solutions in Business                                                                       │
# │  A. Benefits of AI Adoption for Small and Medium Enterprises                                                    │
# │  B. Steps to Successfully Deploy AI Technologies                                                                │
# │  C. Challenges and Solutions in AI Integration                                                                  │
# │  D. Case Studies of Businesses Leveraging AI for Growth                                                         │
# │                                                                                                                 │
# │  VI. Ethics and Transparency in AI                                                                              │
# │  A. Ensuring Fairness and Accountability in AI Systems                                                          │
# │  B. Addressing Bias and Diversity in AI Algorithms                                                              │
# │  C. Industry Initiatives Promoting Ethical AI Practices                                                         │
# │                                                                                                                 │
# │  VII. Call to Action                                                                                            │
# │  - Encouraging Continued Learning through AI Webinars and Courses                                               │
# │  - Engaging with AI Communities and Forums for Insights                                                         │
# │  - Exploring AI Solutions for Personal or Business Use                                                          │
# │                                                                                                                 │
# │  Resources:                                                                                                     │
# │  1. Forbes AI Section for Latest Industry News                                                                  │
# │  2. OpenAI Blog for AI Research and Insights                                                                    │
# │  3. World Economic Forum's AI Initiative Reports                                                                │
# │  4. AI Ethics Guidelines by IEEE and ACM                                                                        │
# │                                                                                                                 │
# │  Content:                                                                                                       │
# │  [Your completed content will be placed here.]                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │  Task: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.                      │
# │  2. Incorporate SEO keywords naturally.                                                                         │
# │  3. Sections/Subtitles are properly named in an engaging manner.                                                │
# │  4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing             │
# │  conclusion.                                                                                                    │
# │  5. Proofread for grammatical errors and alignment with the brand's voice.                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Delving into Artificial Intelligence: Navigating Trends, Players, and News                                   │
# │                                                                                                                 │
# │  In a world driven by technological advancements, Artificial Intelligence (AI) stands at the forefront of       │
# │  innovation, revolutionizing how businesses operate and individuals interact with technology. At its core, AI   │
# │  refers to the simulation of human intelligence processes by machines, enabling them to learn, adapt, and       │
# │  perform tasks autonomously. This transformative technology holds immense significance in today's digital       │
# │  landscape, reshaping industries, optimizing processes, and paving the way for groundbreaking solutions.        │
# │                                                                                                                 │
# │  ## **Unveiling the Latest Trends in Artificial Intelligence**                                                  │
# │                                                                                                                 │
# │  The landscape of AI is marked by dynamic trends that are shaping the future of technology. Machine Learning    │
# │  and Deep Learning continue to make strides, empowering machines to analyze vast datasets, recognize patterns,  │
# │  and make complex decisions. The rise of Conversational AI and Chatbots has revolutionized customer             │
# │  interactions, enabling personalized and efficient communication. Moreover, AI-powered automation is            │
# │  streamlining business processes, enhancing productivity, and driving operational efficiencies. As AI           │
# │  integration expands, addressing ethical considerations and mitigating biases in AI algorithms become           │
# │  imperative to ensure responsible and equitable use of this technology.                                         │
# │                                                                                                                 │
# │  ## **Key Players Driving Innovation in AI**                                                                    │
# │                                                                                                                 │
# │  In the realm of AI, key players are instrumental in driving innovation and setting industry standards. Tech    │
# │  titans like Google, Amazon, Microsoft, and Apple are leading the charge with cutting-edge AI research,         │
# │  products, and services that shape the digital landscape. Additionally, renowned AI research institutes such    │
# │  as the MIT AI Lab and Stanford HAI are pushing the boundaries of AI capabilities, fostering collaboration,     │
# │  and driving groundbreaking discoveries. Emerging AI startups are also making waves by disrupting traditional   │
# │  industries and pioneering novel AI applications that address real-world challenges and opportunities.          │
# │                                                                                                                 │
# │  Artificial Intelligence continues to evolve and permeate various facets of our lives, offering immense         │
# │  potential for growth and transformation. By staying informed about the latest trends, engaging with industry   │
# │  leaders and communities, and embracing ethical AI practices, individuals and businesses can harness the power  │
# │  of AI to thrive in an increasingly digital world. As we navigate the complexities of AI adoption and           │
# │  integration, a proactive and informed approach will be key to unlocking the vast opportunities that AI         │
# │  presents while mitigating potential challenges and ethical implications.                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Editor                                                                                                  │
# │                                                                                                                 │
# │  Task: Proofread the given blog post for grammatical errors and alignment with the brand's voice.               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Editor                                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Delving into Artificial Intelligence: Navigating Trends, Players, and News                                   │
# │                                                                                                                 │
# │  In a rapidly evolving technological landscape, Artificial Intelligence (AI) takes center stage in driving      │
# │  innovation, transforming the operational dynamics of businesses, and reshaping the tech-user interface.        │
# │  Fundamentally, AI involves machines simulating human intelligence processes, enabling them to learn, adapt,    │
# │  and execute tasks independently. This disruptive technology holds profound importance in today's digital       │
# │  arena, redefining sectors, streamlining operations, and fostering revolutionary solutions.                     │
# │                                                                                                                 │
# │  ## Unveiling the Latest Trends in Artificial Intelligence                                                      │
# │                                                                                                                 │
# │  The realm of AI exhibits a dynamic array of trends that are molding the trajectory of technology.              │
# │  Advancements in Machine Learning and Deep Learning persist in empowering machines to sift through extensive    │
# │  datasets, discern patterns, and make intricate decisions. The emergence of Conversational AI and Chatbots has  │
# │  redefined customer engagements, facilitating personalized and efficient interactions. Furthermore, AI-driven   │
# │  automation is optimizing business workflows, boosting productivity, and catalyzing operational efficiencies.   │
# │  With the widening adoption of AI, addressing ethical considerations and mitigating biases in AI algorithms     │
# │  are pivotal steps towards ensuring responsible and equitable AI utilization.                                   │
# │                                                                                                                 │
# │  ## Key Players Driving Innovation in AI                                                                        │
# │                                                                                                                 │
# │  Within the domain of AI, influential players play a pivotal role in propelling innovation and setting          │
# │  benchmarks for the industry. Tech giants like Google, Amazon, Microsoft, and Apple spearhead the AI landscape  │
# │  with trailblazing research, products, and services that shape the digital realm. Additionally, esteemed AI     │
# │  research institutions such as the MIT AI Lab and Stanford HAI continuously push the envelope of AI             │
# │  capabilities, fostering collaborative efforts and driving groundbreaking breakthroughs. Emerging AI startups   │
# │  are also making waves by disrupting conventional industries and pioneering novel AI applications that tackle   │
# │  real-world challenges and opportunities head-on.                                                               │
# │                                                                                                                 │
# │  Artificial Intelligence continues its evolution, permeating diverse facets of society and offering vast        │
# │  prospects for growth and metamorphosis. By staying abreast of the latest trends, engaging with industry        │
# │  figureheads and communities, and embracing ethical AI practices, individuals and enterprises can leverage the  │
# │  potential of AI to thrive in a progressively digital world. As we navigate the intricacies of AI adoption and  │
# │  integration, adopting a proactive and informed stance will be instrumental in harnessing the manifold          │
# │  opportunities AI presents, while concurrently addressing potential challenges and ethical considerations.      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ┌───────────────────────── Tracing Preference Saved ──────────────────────────┐
# │                                                                             │
# │  Info: Tracing has been disabled.                                           │
# │                                                                             │
# │  Your preference has been saved. Future Crew/Flow executions will not       │
# │  collect traces.                                                            │
# │                                                                             │
# │  To enable tracing later, do any one of these:                              │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
